# %% [markdown]
# <a href="https://colab.research.google.com/github/ThamaraCrispim/Python-learning-journey/blob/main/Introdu%C3%A7%C3%A3o_ao_Python_03_RECEBENDO_DADOS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nome = input('Qual é o seu nome?')
# Out:
# Qual é o seu nome?Thamara

# %% [markdown]
# Gabi

# %% [markdown]
# ## **Exercícios**

# %%
#Faça um programa que dê bom dia;
print('Bom dia!')
# Out:
# Bom dia!

# %%
#Faça um programa que de bom dia, pergunta o nome da pessoa
# e responde que é um prazer conhecer ela, citando o nome da pessoa

a = input('Bom dia, tudo bem? qual é o seu dia?')
print('Pazer em conhece você', a)
# Out:
# Bom dia, tudo bem? qual é o seu dia?thamara
# Pazer em conhece você thamara

# %%
#Faça um programa que receba um número inteiro e caçculo sua raiz quadrada e exiba o resultado.
a = int(input('Digita um valor:'))
raiz_quadrada = a ** 0,5

print('A raiz quadrada de', a ,'é', raiz_quadrada)
# Out:
# Digita um valor:4
# A raiz quadrada de 4 é (1, 5)

# %%
#Faça um programa que exiba o dobro de um número inserido pela usuário
a = int(input('Digita um valor:'))
d = a * 2
print('Numero que você escolheu', a , 'O dobro é', d)
# Out:
# Digita um valor:2
# Numero que você escolheu 2 O dobro é 4
